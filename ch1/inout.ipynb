# %% [markdown]
# # 표준 입출력
# - 표준 입력 : 키보드 => input()
# - 표준 출력 : 모니터 => print()

# %%
num = input("숫자 입력")

if num.isdigit() : 
    int(num) + 10
    print(num)
else :
    print("숫자를 입력하세요")
# Out:
# 숫자를 입력하세요
